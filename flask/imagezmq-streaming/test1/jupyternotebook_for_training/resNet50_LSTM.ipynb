# %%
# %tensorflow_version 1.x
import keras

# %% [markdown]
# ## ResNet50 + LSTM

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.models import Model
from keras.layers import Dense, Input, Flatten, MaxPooling2D, BatchNormalization, ReLU, Conv2D
from keras.layers.pooling import GlobalAveragePooling2D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import TimeDistributed
from keras.optimizers import Nadam
from keras.backend import flatten
from keras.activations import relu

IMG_WIDTH = 224
IMG_HEIGHT = 224
frame_len = 16

video = Input(shape=(frame_len,
                     IMG_WIDTH,
                     IMG_HEIGHT,
                     3))
# cnn_base = VGG16(include_top=False,
#                  input_shape=(224,
#                               224,
#                               3),
#                  weights="imagenet",
#                  )
cnn_base = ResNet50(include_top = False,
                    input_shape = (IMG_WIDTH,
                                IMG_HEIGHT, 3),
                    weights="imagenet")
cnn_base.trainable = True
cnn_out = Conv2D(1024, kernel_size=(1,1), strides=(1,1), activation=None)(cnn_base.output)
cnn_out = BatchNormalization()(cnn_out)
cnn_out = ReLU()(cnn_out)
cnn_out = Conv2D(512, kernel_size=(2,2), strides=(2,2), activation=None)(cnn_out)
cnn_out = BatchNormalization()(cnn_out)
cnn_out = ReLU()(cnn_out)
cnn_out = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(cnn_out)
cnn_out = Flatten()(cnn_out)

# cnn_out = GlobalAveragePooling2D()(cnn_base.output)
cnn_out = Dense(output_dim=1024, activation="tanh")(cnn_out)
cnn = Model(input=cnn_base.input, output=cnn_out)
cnn.trainable = True
encoded_frames = TimeDistributed(cnn)(video)
encoded_sequence = LSTM(512, activation='tanh', dropout=0.5, return_sequences = True, name="lstm")(encoded_frames)
encoded_sequence = Flatten()(encoded_sequence)
hidden_layer = Dense(output_dim=1024, activation="relu")(encoded_sequence)
outputs = Dense(output_dim=3, activation="softmax")(hidden_layer)
model = Model([video], outputs)

# %%
model.summary()

# %% [markdown]
# ## video generator install

# %%
# !pip install keras-video-generators

# %% [markdown]
# ## Preprocessing method for train

# %%
def get_random_crop(image, crop_x, crop_y, crop_height, crop_width):



    crop = image[crop_y: crop_y + crop_height, crop_x: crop_x + crop_width]

    return crop

# %% [markdown]
# ## Preprocessing method for validation

# %%
def crop_center(img, new_size):
    y, x, c = img.shape
    (cropx, cropy) = new_size
    startx = x // 2 - (cropx // 2)
    starty = y // 2 - (cropy // 2)
    return img[starty:starty + cropy, startx:startx + cropx]

# %% [markdown]
# ## Custom Video generator class for train

# %%
from keras_video import VideoFrameGenerator
from math import floor
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, img_to_array

class VideoFrameGenerator_RGB(VideoFrameGenerator):
    def _get_frames(self, video, nbframe, shape, force_no_headers=False):
        cap = cv2.VideoCapture(video)
        total_frames = self.count_frames(cap, video, force_no_headers)
        frame_step = int(np.random.randint(total_frames-nbframe, size=1)) # 시작 프레임 랜덤으로 정의
        # TODO: fix that, a tiny video can have a frame_step that is
        # under 1
        frame_step = max(1, frame_step)
        frames = []
        frame_i = 0
        crop_width = 224
        crop_height = 224
        max_x = shape[1] - crop_width
        max_y = shape[0] - crop_height

        crop_x = np.random.randint(0, max_x)
        crop_y = np.random.randint(0, max_y)
        while True:
            grabbed, frame = cap.read()
            if not grabbed:
                break

            frame_i += 1
            if frame_i >= frame_step: # 랜덤으로 정의된 값보다 크면
                # resize
                frame = cv2.resize(frame, shape)  ## 256, 256으로 리사이징
                                
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) ## 모델에 넣기 위해 RGB 채널로 변경
                
                #to np
                frame = img_to_array(frame) 
                
                frame = get_random_crop(frame, crop_x, crop_y,  crop_width, crop_height) ## 데이터 증강을 위한 랜덤 크롭
                frame = (frame - frame.mean()) / frame.std()
                
                frames.append(frame)
            if len(frames) == nbframe:
                break
        cap.release()

        if not force_no_headers and len(frames) != nbframe:
            # There is a problem here
            # That means that frame count in header is wrong or broken,
            # so we need to force the full read of video to get the right
            # frame counter
            return self._get_frames(
                    video,
                    nbframe,
                    shape,
                    force_no_headers=True)

        if force_no_headers and len(frames) != nbframe:
            # and if we really couldn't find the real frame counter
            # so we return None. Sorry, nothing can be done...
            log.error("Frame count is not OK for video %s, "
                      "%d total, %d extracted" % (
                        video, total_frames, len(frames)))
            return None
        return np.array(frames)
    
    def __getitem__(self, index): ## 데이터 증강 후 0~255 사이의 값이기 때문에 255로 나눠줌
        classes = self.classes
        shape = self.target_shape
        nbframe = self.nbframe

        labels = []
        images = []

        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        transformation = None

        for i in indexes:
            # prepare a transformation if provided
            if self.transformation is not None:
                transformation = self._random_trans[i]

            video = self.files[i]
            classname = self._get_classname(video)

            # create a label array and set 1 to the right column
            label = np.zeros(len(classes))
            col = classes.index(classname)
            label[col] = 1.


            frames = self._get_frames(
                video,
                nbframe,
                shape,
                force_no_headers=not self.use_video_header)
            if frames is None:
                # avoid failure, nevermind that video...
                continue

            # apply transformation
            if transformation is not None:
                frames = [self.transformation.apply_transform(
                    frame, transformation) for frame in frames]

            # add the sequence in batch
            images.append(frames)
            labels.append(label)

        return np.array(images), np.array(labels)

# %% [markdown]
# ## Custom Video generator class for Val

# %%
from keras_video import VideoFrameGenerator
from math import floor
import cv2
import numpy as np
class VideoFrameGenerator_RGB_val(VideoFrameGenerator):
    def _get_frames(self, video, nbframe, shape, force_no_headers=False):
        cap = cv2.VideoCapture(video)
        total_frames = self.count_frames(cap, video, force_no_headers)
        frame_step = int(np.random.randint(total_frames-nbframe, size=1))  # 시작 프레임 랜덤으로 정의
        # TODO: fix that, a tiny video can have a frame_step that is
        # under 1
        frame_step = max(1, frame_step)
        frames = []
        frame_i = 0

        while True:
            grabbed, frame = cap.read()
            if not grabbed:
                break

            frame_i += 1
            if frame_i >= frame_step:  # 랜덤으로 정의된 값보다 크면
                # resize
                frame = cv2.resize(frame, shape)  ## 224, 224으로 리사이징
                frame = crop_center(frame, (224, 224))
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  ## 모델에 넣기 위해 RGB 채널로 변경
                
                #to np
                frame = img_to_array(frame)
                frame = (frame - frame.mean()) / frame.std()
                
                frames.append(frame)
            if len(frames) == nbframe:
                break

        cap.release()

        if not force_no_headers and len(frames) != nbframe:
            # There is a problem here
            # That means that frame count in header is wrong or broken,
            # so we need to force the full read of video to get the right
            # frame counter
            return self._get_frames(
                    video,
                    nbframe,
                    shape,
                    force_no_headers=True)

        if force_no_headers and len(frames) != nbframe:
            # and if we really couldn't find the real frame counter
            # so we return None. Sorry, nothing can be done...
            log.error("Frame count is not OK for video %s, "
                      "%d total, %d extracted" % (
                        video, total_frames, len(frames)))
            return None

        return np.array(frames)

# %% [markdown]
# ## call Generator and data augmentation for train

# %%
from keras_video import VideoFrameGenerator
import os
import glob
import keras
NBFRAME = 16
classes = [i.split(os.path.sep)[-1] for i in glob.glob('drive/My Drive/Dataset/final_project/Image/*')]
classes.sort()
# some global params
SIZE = (256, 256)
CHANNELS = 1
BS = 4
# pattern to get videos and classes
glob_pattern='./drive/My Drive/Dataset/final_project/Image/{classname}/*.mp4'

# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    # zoom_range=.2,
    # brightness_range=[0.7, 1.3],
    # rotation_range = 20,
    horizontal_flip=True,
    width_shift_range=.2,
    height_shift_range=.2
    )
# Create video frame generator
train = VideoFrameGenerator_RGB(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    shuffle=True,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    transformation=data_aug,
    use_frame_cache=True)

# %% [markdown]
# ## call Generator for val

# %%
glob_pattern='./drive/My Drive/Dataset/final_project/Val/{classname}/*.mp4'

valid = VideoFrameGenerator_RGB_val(
    rescale=1./255,
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME, 
    batch_size=16,
    target_shape=(256, 256),
    nb_channel=CHANNELS,
    use_frame_cache=True)

# %% [markdown]
# ## define recall method

# %%
def single_class_recall(interesting_class_id):
    def recall(y_true, y_pred):
        class_id_true = keras.backend.argmax(y_true, axis=-1)
        class_id_pred = keras.backend.argmax(y_pred, axis=-1)
        recall_mask = keras.backend.cast(keras.backend.equal(class_id_true, interesting_class_id), 'int32')
        class_recall_tensor = keras.backend.cast(keras.backend.equal(class_id_true, class_id_pred), 'int32') * recall_mask
        class_recall = keras.backend.cast(keras.backend.sum(class_recall_tensor), 'float32') / keras.backend.cast(keras.backend.maximum(keras.backend.sum(recall_mask), 1), 'float32')
        return class_recall
    return recall

# %% [markdown]
# ## model compile

# %%
model.compile(loss="categorical_crossentropy",
                optimizer=keras.optimizers.SGD(lr=0.1, momentum=0.9, decay=0.9)
            , metrics=['accuracy', single_class_recall(0), single_class_recall(1), single_class_recall(2)])

# %% [markdown]
# # Tensorboard 사용 (For colab)

# %%
LOG_DIR = '/tmp/log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip ngrok-stable-linux-amd64.zip

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://6352c9bd.ngrok.io

# %% [markdown]
# ## define callback methods for train

# %%
EPOCHS = 20000
callbacks = [

    keras.callbacks.ModelCheckpoint('drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5', 
                                              monitor='loss', 
                                              verbose=1, save_best_only=True, save_weights_only=True, 
                                              mode='auto', period=1),
    keras.callbacks.TensorBoard(log_dir='/tmp/log', histogram_freq=0, write_graph=True, update_freq='epoch', write_images=True),
]

# %% [markdown]
# ## model train

# %%
model.fit_generator(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/20000
# 143/143 [==============================] - 334s 2s/step - loss: 1.4061 - accuracy: 0.3549 - recall: 0.5385 - val_loss: 1.0795 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00001: loss improved from inf to 1.40615, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/20000
# 143/143 [==============================] - 98s 688ms/step - loss: 1.0973 - accuracy: 0.3706 - recall: 0.7902 - val_loss: 1.0383 - val_accuracy: 0.6562 - val_recall: 1.0000
#
# Epoch 00002: loss improved from 1.40615 to 1.09730, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 3/20000
# 143/143 [==============================] - 99s 689ms/step - loss: 1.0961 - accuracy: 0.3706 - recall: 0.8182 - val_loss: 1.0577 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00003: loss improved from 1.09730 to 1.09610, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 4/20000
# 143/143 [==============================] - 98s 684ms/step - loss: 1.0959 - accuracy: 0.3706 - recall: 0.8392 - val_loss: 1.0762 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00004: loss improved from 1.09610 to 1.09591, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 5/20000
# 143/143 [==============================] - 98s 685ms/step - loss: 1.0953 - accuracy: 0.3706 - recall: 0.8252 - val_loss: 1.0450 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00005: loss improved from 1.09591 to 1.09533, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 6/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0944 - accuracy: 0.3706 - recall: 0.8601 - val_loss: 1.0756 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00006: loss improved from 1.09533 to 1.09438, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 7/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0941 - accuracy: 0.3689 - recall: 0.8531 - val_loss: 1.0518 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00007: loss improved from 1.09438 to 1.09412, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 8/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0936 - accuracy: 0.3706 - recall: 0.8392 - val_loss: 1.0494 - val_accuracy: 0.5000 - val_recall: 1.0000
#
# Epoch 00008: loss improved from 1.09412 to 1.09358, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 9/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0954 - accuracy: 0.3689 - recall: 0.8252 - val_loss: 1.0736 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00009: loss did not improve from 1.09358
# Epoch 10/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0940 - accuracy: 0.3706 - recall: 0.8252 - val_loss: 1.0239 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00010: loss did not improve from 1.09358
# Epoch 11/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0926 - accuracy: 0.3706 - recall: 0.8741 - val_loss: 1.0537 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00011: loss improved from 1.09358 to 1.09263, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 12/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0922 - accuracy: 0.3706 - recall: 0.8182 - val_loss: 1.0379 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00012: loss improved from 1.09263 to 1.09224, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 13/20000
# 143/143 [==============================] - 97s 682ms/step - loss: 1.0944 - accuracy: 0.3706 - recall: 0.8601 - val_loss: 1.0797 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00013: loss did not improve from 1.09224
# Epoch 14/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0922 - accuracy: 0.3706 - recall: 0.8811 - val_loss: 1.0584 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00014: loss improved from 1.09224 to 1.09223, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 15/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0925 - accuracy: 0.3706 - recall: 0.8112 - val_loss: 1.0503 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00015: loss did not improve from 1.09223
# Epoch 16/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0920 - accuracy: 0.3689 - recall: 0.8252 - val_loss: 1.0812 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00016: loss improved from 1.09223 to 1.09201, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 17/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0930 - accuracy: 0.3689 - recall: 0.8112 - val_loss: 1.0599 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00017: loss did not improve from 1.09201
# Epoch 18/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0912 - accuracy: 0.3724 - recall: 0.8392 - val_loss: 1.0403 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00018: loss improved from 1.09201 to 1.09116, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 19/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0905 - accuracy: 0.3724 - recall: 0.8671 - val_loss: 1.0505 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00019: loss improved from 1.09116 to 1.09050, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 20/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0903 - accuracy: 0.3689 - recall: 0.8741 - val_loss: 1.0524 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00020: loss improved from 1.09050 to 1.09026, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 21/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0909 - accuracy: 0.3689 - recall: 0.8578 - val_loss: 1.0467 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00021: loss did not improve from 1.09026
# Epoch 22/20000
# 143/143 [==============================] - 96s 669ms/step - loss: 1.0916 - accuracy: 0.3689 - recall: 0.8322 - val_loss: 1.0370 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00022: loss did not improve from 1.09026
# Epoch 23/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0932 - accuracy: 0.3706 - recall: 0.8811 - val_loss: 1.0414 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00023: loss did not improve from 1.09026
# Epoch 24/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0915 - accuracy: 0.3689 - recall: 0.8706 - val_loss: 1.0557 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00024: loss did not improve from 1.09026
# Epoch 25/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0920 - accuracy: 0.3706 - recall: 0.8357 - val_loss: 1.0587 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00025: loss did not improve from 1.09026
# Epoch 26/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0922 - accuracy: 0.3689 - recall: 0.8287 - val_loss: 1.0530 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00026: loss did not improve from 1.09026
# Epoch 27/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0920 - accuracy: 0.3706 - recall: 0.8298 - val_loss: 1.0541 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00027: loss did not improve from 1.09026
# Epoch 28/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0910 - accuracy: 0.3706 - recall: 0.8462 - val_loss: 1.0780 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00028: loss did not improve from 1.09026
# Epoch 29/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0918 - accuracy: 0.3741 - recall: 0.8636 - val_loss: 1.0506 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00029: loss did not improve from 1.09026
# Epoch 30/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0947 - accuracy: 0.3706 - recall: 0.8776 - val_loss: 1.0807 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00030: loss did not improve from 1.09026
# Epoch 31/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0906 - accuracy: 0.3636 - recall: 0.8100 - val_loss: 1.0399 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00031: loss did not improve from 1.09026
# Epoch 32/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0891 - accuracy: 0.3724 - recall: 0.8333 - val_loss: 1.0707 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00032: loss improved from 1.09026 to 1.08912, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 33/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0909 - accuracy: 0.3671 - recall: 0.8508 - val_loss: 1.0846 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00033: loss did not improve from 1.08912
# Epoch 34/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0883 - accuracy: 0.3741 - recall: 0.8531 - val_loss: 1.0199 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00034: loss improved from 1.08912 to 1.08835, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 35/20000
# 143/143 [==============================] - 96s 669ms/step - loss: 1.0904 - accuracy: 0.3759 - recall: 0.8741 - val_loss: 1.0625 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00035: loss did not improve from 1.08835
# Epoch 36/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0901 - accuracy: 0.3706 - recall: 0.8357 - val_loss: 1.0371 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00036: loss did not improve from 1.08835
# Epoch 37/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0929 - accuracy: 0.3706 - recall: 0.8403 - val_loss: 1.0588 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00037: loss did not improve from 1.08835
# Epoch 38/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0932 - accuracy: 0.3671 - recall: 0.7733 - val_loss: 1.0747 - val_accuracy: 0.5000 - val_recall: 1.0000
#
# Epoch 00038: loss did not improve from 1.08835
# Epoch 39/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0926 - accuracy: 0.3689 - recall: 0.8357 - val_loss: 1.0353 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00039: loss did not improve from 1.08835
# Epoch 40/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0898 - accuracy: 0.3829 - recall: 0.8514 - val_loss: 1.0096 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00040: loss did not improve from 1.08835
# Epoch 41/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0917 - accuracy: 0.3671 - recall: 0.8124 - val_loss: 1.0193 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00041: loss did not improve from 1.08835
# Epoch 42/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0910 - accuracy: 0.3776 - recall: 0.8333 - val_loss: 1.0342 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00042: loss did not improve from 1.08835
# Epoch 43/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0896 - accuracy: 0.3776 - recall: 0.7978 - val_loss: 1.0664 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00043: loss did not improve from 1.08835
# Epoch 44/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0942 - accuracy: 0.3776 - recall: 0.8345 - val_loss: 1.0568 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00044: loss did not improve from 1.08835
# Epoch 45/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0908 - accuracy: 0.3671 - recall: 0.8089 - val_loss: 1.0240 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00045: loss did not improve from 1.08835
# Epoch 46/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0914 - accuracy: 0.3706 - recall: 0.7873 - val_loss: 1.0379 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00046: loss did not improve from 1.08835
# Epoch 47/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0887 - accuracy: 0.3724 - recall: 0.7809 - val_loss: 1.0454 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00047: loss did not improve from 1.08835
# Epoch 48/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0898 - accuracy: 0.3654 - recall: 0.7500 - val_loss: 1.0173 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00048: loss did not improve from 1.08835
# Epoch 49/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0936 - accuracy: 0.3706 - recall: 0.7716 - val_loss: 1.0755 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00049: loss did not improve from 1.08835
# Epoch 50/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0874 - accuracy: 0.3864 - recall: 0.8042 - val_loss: 1.0478 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00050: loss improved from 1.08835 to 1.08742, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 51/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0899 - accuracy: 0.3951 - recall: 0.8112 - val_loss: 1.0236 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00051: loss did not improve from 1.08742
# Epoch 52/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0909 - accuracy: 0.3741 - recall: 0.7902 - val_loss: 1.0369 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00052: loss did not improve from 1.08742
# Epoch 53/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0868 - accuracy: 0.3846 - recall: 0.8316 - val_loss: 1.0449 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00053: loss improved from 1.08742 to 1.08682, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 54/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0894 - accuracy: 0.3881 - recall: 0.7704 - val_loss: 1.0282 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00054: loss did not improve from 1.08682
# Epoch 55/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0910 - accuracy: 0.3829 - recall: 0.8071 - val_loss: 1.0537 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00055: loss did not improve from 1.08682
# Epoch 56/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0863 - accuracy: 0.3864 - recall: 0.8362 - val_loss: 1.0666 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00056: loss improved from 1.08682 to 1.08630, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 57/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0918 - accuracy: 0.3724 - recall: 0.7791 - val_loss: 1.0748 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00057: loss did not improve from 1.08630
# Epoch 58/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0907 - accuracy: 0.3706 - recall: 0.7331 - val_loss: 1.0346 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00058: loss did not improve from 1.08630
# Epoch 59/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0869 - accuracy: 0.3934 - recall: 0.8322 - val_loss: 1.0829 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00059: loss did not improve from 1.08630
# Epoch 60/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0870 - accuracy: 0.3916 - recall: 0.8147 - val_loss: 1.0717 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00060: loss did not improve from 1.08630
# Epoch 61/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0932 - accuracy: 0.3794 - recall: 0.7972 - val_loss: 1.0599 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00061: loss did not improve from 1.08630
# Epoch 62/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0905 - accuracy: 0.3881 - recall: 0.7663 - val_loss: 1.0377 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00062: loss did not improve from 1.08630
# Epoch 63/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0882 - accuracy: 0.3829 - recall: 0.7815 - val_loss: 1.0113 - val_accuracy: 0.6562 - val_recall: 1.0000
#
# Epoch 00063: loss did not improve from 1.08630
# Epoch 64/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0903 - accuracy: 0.3916 - recall: 0.7721 - val_loss: 1.0314 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00064: loss did not improve from 1.08630
# Epoch 65/20000
# 143/143 [==============================] - 98s 685ms/step - loss: 1.0896 - accuracy: 0.3934 - recall: 0.8106 - val_loss: 1.0472 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00065: loss did not improve from 1.08630
# Epoch 66/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0873 - accuracy: 0.4178 - recall: 0.8345 - val_loss: 1.0238 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00066: loss did not improve from 1.08630
# Epoch 67/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0870 - accuracy: 0.3794 - recall: 0.7768 - val_loss: 1.0393 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00067: loss did not improve from 1.08630
# Epoch 68/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0894 - accuracy: 0.3881 - recall: 0.7984 - val_loss: 1.0425 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00068: loss did not improve from 1.08630
# Epoch 69/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0851 - accuracy: 0.3986 - recall: 0.8135 - val_loss: 1.0059 - val_accuracy: 0.5625 - val_recall: 0.9286
#
# Epoch 00069: loss improved from 1.08630 to 1.08506, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 70/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0881 - accuracy: 0.3829 - recall: 0.8164 - val_loss: 1.0694 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00070: loss did not improve from 1.08506
# Epoch 71/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0899 - accuracy: 0.3846 - recall: 0.7354 - val_loss: 1.0480 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00071: loss did not improve from 1.08506
# Epoch 72/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0909 - accuracy: 0.3671 - recall: 0.7284 - val_loss: 1.0584 - val_accuracy: 0.5938 - val_recall: 0.9583
#
# Epoch 00072: loss did not improve from 1.08506
# Epoch 73/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0859 - accuracy: 0.3951 - recall: 0.7721 - val_loss: 1.0594 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00073: loss did not improve from 1.08506
# Epoch 74/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0888 - accuracy: 0.3899 - recall: 0.7576 - val_loss: 1.0246 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00074: loss did not improve from 1.08506
# Epoch 75/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0856 - accuracy: 0.4056 - recall: 0.8502 - val_loss: 1.0195 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00075: loss did not improve from 1.08506
# Epoch 76/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0906 - accuracy: 0.3794 - recall: 0.7803 - val_loss: 1.0560 - val_accuracy: 0.5000 - val_recall: 0.9000
#
# Epoch 00076: loss did not improve from 1.08506
# Epoch 77/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0880 - accuracy: 0.4038 - recall: 0.7337 - val_loss: 1.0580 - val_accuracy: 0.5000 - val_recall: 1.0000
#
# Epoch 00077: loss did not improve from 1.08506
# Epoch 78/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0875 - accuracy: 0.3951 - recall: 0.7867 - val_loss: 1.0299 - val_accuracy: 0.5000 - val_recall: 0.9500
#
# Epoch 00078: loss did not improve from 1.08506
# Epoch 79/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0908 - accuracy: 0.3846 - recall: 0.6568 - val_loss: 1.0448 - val_accuracy: 0.5312 - val_recall: 0.8944
#
# Epoch 00079: loss did not improve from 1.08506
# Epoch 80/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0867 - accuracy: 0.3951 - recall: 0.7611 - val_loss: 1.0596 - val_accuracy: 0.5312 - val_recall: 0.8920
#
# Epoch 00080: loss did not improve from 1.08506
# Epoch 81/20000
# 143/143 [==============================] - 96s 668ms/step - loss: 1.0920 - accuracy: 0.3811 - recall: 0.7325 - val_loss: 1.0430 - val_accuracy: 0.5000 - val_recall: 0.9000
#
# Epoch 00081: loss did not improve from 1.08506
# Epoch 82/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0874 - accuracy: 0.3759 - recall: 0.7506 - val_loss: 1.0510 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00082: loss did not improve from 1.08506
# Epoch 83/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0913 - accuracy: 0.3829 - recall: 0.7657 - val_loss: 1.0575 - val_accuracy: 0.4688 - val_recall: 0.8889
#
# Epoch 00083: loss did not improve from 1.08506
# Epoch 84/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0883 - accuracy: 0.3951 - recall: 0.7698 - val_loss: 1.0332 - val_accuracy: 0.4688 - val_recall: 0.8750
#
# Epoch 00084: loss did not improve from 1.08506
# Epoch 85/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0865 - accuracy: 0.3916 - recall: 0.7704 - val_loss: 1.0425 - val_accuracy: 0.5938 - val_recall: 0.9444
#
# Epoch 00085: loss did not improve from 1.08506
# Epoch 86/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0873 - accuracy: 0.4108 - recall: 0.7459 - val_loss: 1.0341 - val_accuracy: 0.4688 - val_recall: 0.8750
#
# Epoch 00086: loss did not improve from 1.08506
# Epoch 87/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0902 - accuracy: 0.3881 - recall: 0.7972 - val_loss: 1.0594 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00087: loss did not improve from 1.08506
# Epoch 88/20000
# 143/143 [==============================] - 98s 683ms/step - loss: 1.0859 - accuracy: 0.3986 - recall: 0.7611 - val_loss: 1.0719 - val_accuracy: 0.4688 - val_recall: 0.8786
#
# Epoch 00088: loss did not improve from 1.08506
# Epoch 89/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0877 - accuracy: 0.3951 - recall: 0.7424 - val_loss: 1.0471 - val_accuracy: 0.4688 - val_recall: 0.9444
#
# Epoch 00089: loss did not improve from 1.08506
# Epoch 90/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0844 - accuracy: 0.3986 - recall: 0.7570 - val_loss: 1.0711 - val_accuracy: 0.5312 - val_recall: 0.9286
#
# Epoch 00090: loss improved from 1.08506 to 1.08438, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 91/20000
# 143/143 [==============================] - 98s 686ms/step - loss: 1.0892 - accuracy: 0.3951 - recall: 0.7745 - val_loss: 0.9917 - val_accuracy: 0.5938 - val_recall: 0.8889
#
# Epoch 00091: loss did not improve from 1.08438
# Epoch 92/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0895 - accuracy: 0.4021 - recall: 0.7587 - val_loss: 1.0671 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00092: loss did not improve from 1.08438
# Epoch 93/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0880 - accuracy: 0.4056 - recall: 0.7587 - val_loss: 1.0121 - val_accuracy: 0.5625 - val_recall: 0.9167
#
# Epoch 00093: loss did not improve from 1.08438
# Epoch 94/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0932 - accuracy: 0.3916 - recall: 0.6702 - val_loss: 1.0444 - val_accuracy: 0.5000 - val_recall: 0.8889
#
# Epoch 00094: loss did not improve from 1.08438
# Epoch 95/20000
# 143/143 [==============================] - 98s 683ms/step - loss: 1.0901 - accuracy: 0.3776 - recall: 0.7045 - val_loss: 1.0588 - val_accuracy: 0.5312 - val_recall: 0.8920
#
# Epoch 00095: loss did not improve from 1.08438
# Epoch 96/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0892 - accuracy: 0.3969 - recall: 0.7611 - val_loss: 1.0617 - val_accuracy: 0.5000 - val_recall: 0.9091
#
# Epoch 00096: loss did not improve from 1.08438
# Epoch 97/20000
# 143/143 [==============================] - 98s 685ms/step - loss: 1.0892 - accuracy: 0.3881 - recall: 0.7488 - val_loss: 1.0466 - val_accuracy: 0.5000 - val_recall: 0.9444
#
# Epoch 00097: loss did not improve from 1.08438
# Epoch 98/20000
# 143/143 [==============================] - 98s 683ms/step - loss: 1.0896 - accuracy: 0.3864 - recall: 0.7424 - val_loss: 1.0671 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00098: loss did not improve from 1.08438
# Epoch 99/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0893 - accuracy: 0.3969 - recall: 0.7605 - val_loss: 1.0824 - val_accuracy: 0.4688 - val_recall: 0.9500
#
# Epoch 00099: loss did not improve from 1.08438
# Epoch 100/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0855 - accuracy: 0.3916 - recall: 0.7104 - val_loss: 1.0576 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00100: loss did not improve from 1.08438
# Epoch 101/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0845 - accuracy: 0.4021 - recall: 0.7337 - val_loss: 1.0229 - val_accuracy: 0.5000 - val_recall: 0.9545
#
# Epoch 00101: loss did not improve from 1.08438
# Epoch 102/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0874 - accuracy: 0.3829 - recall: 0.6993 - val_loss: 1.0041 - val_accuracy: 0.5312 - val_recall: 0.9286
#
# Epoch 00102: loss did not improve from 1.08438
# Epoch 103/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0901 - accuracy: 0.3934 - recall: 0.7290 - val_loss: 1.0248 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00103: loss did not improve from 1.08438
# Epoch 104/20000
# 143/143 [==============================] - 98s 683ms/step - loss: 1.0878 - accuracy: 0.4003 - recall: 0.7401 - val_loss: 1.0605 - val_accuracy: 0.5000 - val_recall: 0.9500
#
# Epoch 00104: loss did not improve from 1.08438
# Epoch 105/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0831 - accuracy: 0.4021 - recall: 0.7413 - val_loss: 1.0110 - val_accuracy: 0.5000 - val_recall: 0.8831
#
# Epoch 00105: loss improved from 1.08438 to 1.08307, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 106/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0866 - accuracy: 0.3934 - recall: 0.7092 - val_loss: 1.0127 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00106: loss did not improve from 1.08307
# Epoch 107/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0853 - accuracy: 0.4213 - recall: 0.7657 - val_loss: 1.0433 - val_accuracy: 0.4688 - val_recall: 0.8819
#
# Epoch 00107: loss did not improve from 1.08307
# Epoch 108/20000
# 143/143 [==============================] - 97s 682ms/step - loss: 1.0850 - accuracy: 0.4213 - recall: 0.7448 - val_loss: 1.0635 - val_accuracy: 0.5000 - val_recall: 0.8750
#
# Epoch 00108: loss did not improve from 1.08307
# Epoch 109/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0887 - accuracy: 0.3899 - recall: 0.6981 - val_loss: 1.0674 - val_accuracy: 0.5000 - val_recall: 0.9286
#
# Epoch 00109: loss did not improve from 1.08307
# Epoch 110/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0845 - accuracy: 0.4126 - recall: 0.7145 - val_loss: 1.0623 - val_accuracy: 0.5312 - val_recall: 0.9167
#
# Epoch 00110: loss did not improve from 1.08307
# Epoch 111/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0840 - accuracy: 0.4021 - recall: 0.6894 - val_loss: 1.0414 - val_accuracy: 0.5312 - val_recall: 0.8944
#
# Epoch 00111: loss did not improve from 1.08307
# Epoch 112/20000
# 143/143 [==============================] - 98s 683ms/step - loss: 1.0852 - accuracy: 0.4021 - recall: 0.6876 - val_loss: 1.0359 - val_accuracy: 0.4688 - val_recall: 0.9000
#
# Epoch 00112: loss did not improve from 1.08307
# Epoch 113/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0913 - accuracy: 0.3951 - recall: 0.7121 - val_loss: 1.0196 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00113: loss did not improve from 1.08307
# Epoch 114/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0822 - accuracy: 0.4108 - recall: 0.7529 - val_loss: 1.0226 - val_accuracy: 0.5312 - val_recall: 0.8944
#
# Epoch 00114: loss improved from 1.08307 to 1.08216, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 115/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0842 - accuracy: 0.4073 - recall: 0.7016 - val_loss: 1.0296 - val_accuracy: 0.5000 - val_recall: 0.9500
#
# Epoch 00115: loss did not improve from 1.08216
# Epoch 116/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0822 - accuracy: 0.4213 - recall: 0.7232 - val_loss: 1.0408 - val_accuracy: 0.5938 - val_recall: 0.9583
#
# Epoch 00116: loss did not improve from 1.08216
# Epoch 117/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0854 - accuracy: 0.3986 - recall: 0.6807 - val_loss: 1.0209 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00117: loss did not improve from 1.08216
# Epoch 118/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0834 - accuracy: 0.4143 - recall: 0.7797 - val_loss: 1.0624 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00118: loss did not improve from 1.08216
# Epoch 119/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0876 - accuracy: 0.3864 - recall: 0.6783 - val_loss: 1.0210 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00119: loss did not improve from 1.08216
# Epoch 120/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0849 - accuracy: 0.4266 - recall: 0.7057 - val_loss: 1.0710 - val_accuracy: 0.5000 - val_recall: 1.0000
#
# Epoch 00120: loss did not improve from 1.08216
# Epoch 121/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0864 - accuracy: 0.4021 - recall: 0.7028 - val_loss: 1.0303 - val_accuracy: 0.4688 - val_recall: 0.9286
#
# Epoch 00121: loss did not improve from 1.08216
# Epoch 122/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0829 - accuracy: 0.4178 - recall: 0.7261 - val_loss: 1.0502 - val_accuracy: 0.5000 - val_recall: 0.8889
#
# Epoch 00122: loss did not improve from 1.08216
# Epoch 123/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0869 - accuracy: 0.4021 - recall: 0.6748 - val_loss: 1.0228 - val_accuracy: 0.5000 - val_recall: 0.8889
#
# Epoch 00123: loss did not improve from 1.08216
# Epoch 124/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0832 - accuracy: 0.4143 - recall: 0.6999 - val_loss: 1.0521 - val_accuracy: 0.5000 - val_recall: 0.9444
#
# Epoch 00124: loss did not improve from 1.08216
# Epoch 125/20000
# 143/143 [==============================] - 96s 675ms/step - loss: 1.0891 - accuracy: 0.3776 - recall: 0.6911 - val_loss: 1.0142 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00125: loss did not improve from 1.08216
# Epoch 126/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0882 - accuracy: 0.3916 - recall: 0.7139 - val_loss: 1.0023 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00126: loss did not improve from 1.08216
# Epoch 127/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0879 - accuracy: 0.4003 - recall: 0.7174 - val_loss: 1.0630 - val_accuracy: 0.5000 - val_recall: 0.8750
#
# Epoch 00127: loss did not improve from 1.08216
# Epoch 128/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0873 - accuracy: 0.3951 - recall: 0.7133 - val_loss: 1.0197 - val_accuracy: 0.5000 - val_recall: 0.9500
#
# Epoch 00128: loss did not improve from 1.08216
# Epoch 129/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0839 - accuracy: 0.4038 - recall: 0.6946 - val_loss: 1.0144 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00129: loss did not improve from 1.08216
# Epoch 130/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0892 - accuracy: 0.4091 - recall: 0.7092 - val_loss: 1.0668 - val_accuracy: 0.5625 - val_recall: 0.9583
#
# Epoch 00130: loss did not improve from 1.08216
# Epoch 131/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0822 - accuracy: 0.4091 - recall: 0.7080 - val_loss: 1.0739 - val_accuracy: 0.5000 - val_recall: 0.9286
#
# Epoch 00131: loss improved from 1.08216 to 1.08216, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 132/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0838 - accuracy: 0.4091 - recall: 0.6812 - val_loss: 0.9987 - val_accuracy: 0.5312 - val_recall: 0.9286
#
# Epoch 00132: loss did not improve from 1.08216
# Epoch 133/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0855 - accuracy: 0.3969 - recall: 0.6900 - val_loss: 1.0572 - val_accuracy: 0.5000 - val_recall: 0.8875
#
# Epoch 00133: loss did not improve from 1.08216
# Epoch 134/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0887 - accuracy: 0.4021 - recall: 0.6585 - val_loss: 1.0911 - val_accuracy: 0.5000 - val_recall: 0.9167
#
# Epoch 00134: loss did not improve from 1.08216
# Epoch 135/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0819 - accuracy: 0.4213 - recall: 0.6737 - val_loss: 1.0487 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00135: loss improved from 1.08216 to 1.08193, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 136/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0833 - accuracy: 0.4003 - recall: 0.7028 - val_loss: 1.0193 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00136: loss did not improve from 1.08193
# Epoch 137/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0867 - accuracy: 0.4143 - recall: 0.7145 - val_loss: 1.0190 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00137: loss did not improve from 1.08193
# Epoch 138/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0843 - accuracy: 0.4178 - recall: 0.6789 - val_loss: 1.0693 - val_accuracy: 0.5000 - val_recall: 0.8831
#
# Epoch 00138: loss did not improve from 1.08193
# Epoch 139/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0879 - accuracy: 0.4056 - recall: 0.6865 - val_loss: 1.0092 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00139: loss did not improve from 1.08193
# Epoch 140/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0837 - accuracy: 0.4091 - recall: 0.7086 - val_loss: 1.0370 - val_accuracy: 0.5000 - val_recall: 0.8889
#
# Epoch 00140: loss did not improve from 1.08193
# Epoch 141/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0856 - accuracy: 0.4003 - recall: 0.7034 - val_loss: 1.0408 - val_accuracy: 0.5000 - val_recall: 0.9000
#
# Epoch 00141: loss did not improve from 1.08193
# Epoch 142/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0819 - accuracy: 0.4108 - recall: 0.7115 - val_loss: 0.9905 - val_accuracy: 0.5938 - val_recall: 0.9000
#
# Epoch 00142: loss improved from 1.08193 to 1.08187, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 143/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0861 - accuracy: 0.3934 - recall: 0.6684 - val_loss: 1.0563 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00143: loss did not improve from 1.08187
# Epoch 144/20000
# 143/143 [==============================] - 95s 668ms/step - loss: 1.0854 - accuracy: 0.4056 - recall: 0.6737 - val_loss: 1.0332 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00144: loss did not improve from 1.08187
# Epoch 145/20000
# 143/143 [==============================] - 95s 667ms/step - loss: 1.0882 - accuracy: 0.3934 - recall: 0.6946 - val_loss: 1.0404 - val_accuracy: 0.5000 - val_recall: 0.9000
#
# Epoch 00145: loss did not improve from 1.08187
# Epoch 146/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0824 - accuracy: 0.4178 - recall: 0.6976 - val_loss: 1.0498 - val_accuracy: 0.4688 - val_recall: 0.8819
#
# Epoch 00146: loss did not improve from 1.08187
# Epoch 147/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0820 - accuracy: 0.4336 - recall: 0.7028 - val_loss: 1.0451 - val_accuracy: 0.5000 - val_recall: 0.8889
#
# Epoch 00147: loss did not improve from 1.08187
# Epoch 148/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0818 - accuracy: 0.4248 - recall: 0.7016 - val_loss: 1.0311 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00148: loss improved from 1.08187 to 1.08175, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 149/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0826 - accuracy: 0.4318 - recall: 0.6935 - val_loss: 1.0507 - val_accuracy: 0.5625 - val_recall: 0.8958
#
# Epoch 00149: loss did not improve from 1.08175
# Epoch 150/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0825 - accuracy: 0.4143 - recall: 0.7220 - val_loss: 1.0397 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00150: loss did not improve from 1.08175
# Epoch 151/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0818 - accuracy: 0.4143 - recall: 0.7436 - val_loss: 1.0304 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00151: loss did not improve from 1.08175
# Epoch 152/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0845 - accuracy: 0.3986 - recall: 0.7028 - val_loss: 1.0284 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00152: loss did not improve from 1.08175
# Epoch 153/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0863 - accuracy: 0.4038 - recall: 0.6894 - val_loss: 0.9646 - val_accuracy: 0.5625 - val_recall: 0.9286
#
# Epoch 00153: loss did not improve from 1.08175
# Epoch 154/20000
# 143/143 [==============================] - 96s 675ms/step - loss: 1.0838 - accuracy: 0.4231 - recall: 0.6824 - val_loss: 0.9959 - val_accuracy: 0.5625 - val_recall: 0.8990
#
# Epoch 00154: loss did not improve from 1.08175
# Epoch 155/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0838 - accuracy: 0.4003 - recall: 0.6649 - val_loss: 1.0316 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00155: loss did not improve from 1.08175
# Epoch 156/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0817 - accuracy: 0.4283 - recall: 0.6906 - val_loss: 1.0414 - val_accuracy: 0.4688 - val_recall: 0.8889
#
# Epoch 00156: loss improved from 1.08175 to 1.08175, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 157/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0868 - accuracy: 0.4178 - recall: 0.6987 - val_loss: 1.0210 - val_accuracy: 0.5312 - val_recall: 0.9000
#
# Epoch 00157: loss did not improve from 1.08175
# Epoch 158/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0850 - accuracy: 0.4126 - recall: 0.7010 - val_loss: 1.0181 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00158: loss did not improve from 1.08175
# Epoch 159/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0844 - accuracy: 0.4038 - recall: 0.7040 - val_loss: 0.9955 - val_accuracy: 0.5625 - val_recall: 0.9583
#
# Epoch 00159: loss did not improve from 1.08175
# Epoch 160/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0854 - accuracy: 0.4073 - recall: 0.6649 - val_loss: 1.0221 - val_accuracy: 0.4688 - val_recall: 0.9286
#
# Epoch 00160: loss did not improve from 1.08175
# Epoch 161/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0841 - accuracy: 0.4178 - recall: 0.7086 - val_loss: 1.0347 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00161: loss did not improve from 1.08175
# Epoch 162/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0849 - accuracy: 0.4091 - recall: 0.7185 - val_loss: 1.0283 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00162: loss did not improve from 1.08175
# Epoch 163/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0836 - accuracy: 0.4021 - recall: 0.7057 - val_loss: 1.0242 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00163: loss did not improve from 1.08175
# Epoch 164/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0908 - accuracy: 0.3916 - recall: 0.6801 - val_loss: 1.0058 - val_accuracy: 0.5000 - val_recall: 0.8750
#
# Epoch 00164: loss did not improve from 1.08175
# Epoch 165/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0804 - accuracy: 0.4371 - recall: 0.7599 - val_loss: 1.0507 - val_accuracy: 0.4688 - val_recall: 0.9000
#
# Epoch 00165: loss improved from 1.08175 to 1.08044, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 166/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0840 - accuracy: 0.4178 - recall: 0.6847 - val_loss: 1.0192 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00166: loss did not improve from 1.08044
# Epoch 167/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0877 - accuracy: 0.4108 - recall: 0.6795 - val_loss: 1.0164 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00167: loss did not improve from 1.08044
# Epoch 168/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0867 - accuracy: 0.4038 - recall: 0.6568 - val_loss: 1.0210 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00168: loss did not improve from 1.08044
# Epoch 169/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0863 - accuracy: 0.3934 - recall: 0.7028 - val_loss: 1.0199 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00169: loss did not improve from 1.08044
# Epoch 170/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0843 - accuracy: 0.4003 - recall: 0.6597 - val_loss: 1.0088 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00170: loss did not improve from 1.08044
# Epoch 171/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0846 - accuracy: 0.4213 - recall: 0.7150 - val_loss: 1.0225 - val_accuracy: 0.5625 - val_recall: 0.9091
#
# Epoch 00171: loss did not improve from 1.08044
# Epoch 172/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0837 - accuracy: 0.4161 - recall: 0.7063 - val_loss: 1.0579 - val_accuracy: 0.5000 - val_recall: 0.8831
#
# Epoch 00172: loss did not improve from 1.08044
# Epoch 173/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0888 - accuracy: 0.3916 - recall: 0.6876 - val_loss: 1.0492 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00173: loss did not improve from 1.08044
# Epoch 174/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0883 - accuracy: 0.4021 - recall: 0.7121 - val_loss: 1.0113 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00174: loss did not improve from 1.08044
# Epoch 175/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0832 - accuracy: 0.4108 - recall: 0.6841 - val_loss: 1.0246 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00175: loss did not improve from 1.08044
# Epoch 176/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0822 - accuracy: 0.4231 - recall: 0.6527 - val_loss: 1.0174 - val_accuracy: 0.5938 - val_recall: 0.9500
#
# Epoch 00176: loss did not improve from 1.08044
# Epoch 177/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0823 - accuracy: 0.4073 - recall: 0.6591 - val_loss: 1.0610 - val_accuracy: 0.5312 - val_recall: 0.9286
#
# Epoch 00177: loss did not improve from 1.08044
# Epoch 178/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0799 - accuracy: 0.4388 - recall: 0.7203 - val_loss: 1.0103 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00178: loss improved from 1.08044 to 1.07992, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 179/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0875 - accuracy: 0.3864 - recall: 0.6766 - val_loss: 1.0287 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00179: loss did not improve from 1.07992
# Epoch 180/20000
# 143/143 [==============================] - 96s 675ms/step - loss: 1.0839 - accuracy: 0.4143 - recall: 0.7156 - val_loss: 1.0142 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00180: loss did not improve from 1.07992
# Epoch 181/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0829 - accuracy: 0.4283 - recall: 0.7005 - val_loss: 1.0254 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00181: loss did not improve from 1.07992
# Epoch 182/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0806 - accuracy: 0.4266 - recall: 0.6900 - val_loss: 1.0071 - val_accuracy: 0.5000 - val_recall: 0.9545
#
# Epoch 00182: loss did not improve from 1.07992
# Epoch 183/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0791 - accuracy: 0.4318 - recall: 0.6719 - val_loss: 1.0169 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00183: loss improved from 1.07992 to 1.07911, saving model to drive/My Drive/Dataset/final_project/LSTM_resnet_RGB.hdf5
# Epoch 184/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0901 - accuracy: 0.4021 - recall: 0.6416 - val_loss: 1.0390 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00184: loss did not improve from 1.07911
# Epoch 185/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0801 - accuracy: 0.4301 - recall: 0.7045 - val_loss: 1.0277 - val_accuracy: 0.5000 - val_recall: 0.9444
#
# Epoch 00185: loss did not improve from 1.07911
# Epoch 186/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0857 - accuracy: 0.4091 - recall: 0.6684 - val_loss: 1.0192 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00186: loss did not improve from 1.07911
# Epoch 187/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0923 - accuracy: 0.3741 - recall: 0.6055 - val_loss: 1.0472 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00187: loss did not improve from 1.07911
# Epoch 188/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0795 - accuracy: 0.4248 - recall: 0.6766 - val_loss: 0.9843 - val_accuracy: 0.5312 - val_recall: 0.9583
#
# Epoch 00188: loss did not improve from 1.07911
# Epoch 189/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0911 - accuracy: 0.3829 - recall: 0.6812 - val_loss: 1.0150 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00189: loss did not improve from 1.07911
# Epoch 190/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0808 - accuracy: 0.4301 - recall: 0.7174 - val_loss: 1.0730 - val_accuracy: 0.5312 - val_recall: 0.9286
#
# ...
# Epoch 318/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0749 - accuracy: 0.4528 - recall: 0.6911 - val_loss: 1.0692 - val_accuracy: 0.5312 - val_recall: 0.9615
#
# Epoch 00318: loss did not improve from 1.07089
# Epoch 319/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0862 - accuracy: 0.3916 - recall: 0.6439 - val_loss: 0.9806 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00319: loss did not improve from 1.07089
# Epoch 320/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0838 - accuracy: 0.4126 - recall: 0.6212 - val_loss: 0.9971 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00320: loss did not improve from 1.07089
# Epoch 321/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0789 - accuracy: 0.4213 - recall: 0.6667 - val_loss: 0.9951 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00321: loss did not improve from 1.07089
# Epoch 322/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0801 - accuracy: 0.4196 - recall: 0.6334 - val_loss: 1.0195 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00322: loss did not improve from 1.07089
# Epoch 323/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0746 - accuracy: 0.4353 - recall: 0.6562 - val_loss: 1.0349 - val_accuracy: 0.5625 - val_recall: 0.9583
#
# Epoch 00323: loss did not improve from 1.07089
# Epoch 324/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0832 - accuracy: 0.4073 - recall: 0.5787 - val_loss: 1.0226 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00324: loss did not improve from 1.07089
# Epoch 325/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0792 - accuracy: 0.4266 - recall: 0.5874 - val_loss: 1.0225 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00325: loss did not improve from 1.07089
# Epoch 326/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0819 - accuracy: 0.4108 - recall: 0.6055 - val_loss: 1.0588 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00326: loss did not improve from 1.07089
# Epoch 327/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0793 - accuracy: 0.4213 - recall: 0.6492 - val_loss: 0.9674 - val_accuracy: 0.5625 - val_recall: 0.9375
#
# Epoch 00327: loss did not improve from 1.07089
# Epoch 328/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0768 - accuracy: 0.4441 - recall: 0.6830 - val_loss: 1.0089 - val_accuracy: 0.5938 - val_recall: 0.9545
#
# Epoch 00328: loss did not improve from 1.07089
# Epoch 329/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0810 - accuracy: 0.4248 - recall: 0.6830 - val_loss: 1.0350 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00329: loss did not improve from 1.07089
# Epoch 330/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0825 - accuracy: 0.4371 - recall: 0.7360 - val_loss: 1.0224 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00330: loss did not improve from 1.07089
# Epoch 331/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0772 - accuracy: 0.4283 - recall: 0.6865 - val_loss: 1.0331 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00331: loss did not improve from 1.07089
# Epoch 332/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0752 - accuracy: 0.4178 - recall: 0.6807 - val_loss: 0.9986 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00332: loss did not improve from 1.07089
# Epoch 333/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0813 - accuracy: 0.4108 - recall: 0.6457 - val_loss: 1.0545 - val_accuracy: 0.5000 - val_recall: 0.9286
#
# Epoch 00333: loss did not improve from 1.07089
# Epoch 334/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0839 - accuracy: 0.4056 - recall: 0.6142 - val_loss: 1.0290 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00334: loss did not improve from 1.07089
# Epoch 335/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0826 - accuracy: 0.4038 - recall: 0.6585 - val_loss: 0.9770 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00335: loss did not improve from 1.07089
# Epoch 336/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0735 - accuracy: 0.4371 - recall: 0.6451 - val_loss: 1.0213 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00336: loss did not improve from 1.07089
# Epoch 337/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0828 - accuracy: 0.4213 - recall: 0.6562 - val_loss: 1.0381 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00337: loss did not improve from 1.07089
# Epoch 338/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0756 - accuracy: 0.4406 - recall: 0.7034 - val_loss: 0.9605 - val_accuracy: 0.5312 - val_recall: 0.9583
#
# Epoch 00338: loss did not improve from 1.07089
# Epoch 339/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0784 - accuracy: 0.4336 - recall: 0.6352 - val_loss: 0.9772 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00339: loss did not improve from 1.07089
# Epoch 340/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0807 - accuracy: 0.4161 - recall: 0.6777 - val_loss: 1.0030 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00340: loss did not improve from 1.07089
# Epoch 341/20000
# 143/143 [==============================] - 96s 675ms/step - loss: 1.0858 - accuracy: 0.4108 - recall: 0.6824 - val_loss: 0.9930 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00341: loss did not improve from 1.07089
# Epoch 342/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0710 - accuracy: 0.4545 - recall: 0.6684 - val_loss: 1.0012 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00342: loss did not improve from 1.07089
# Epoch 343/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0810 - accuracy: 0.4021 - recall: 0.6404 - val_loss: 0.9941 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00343: loss did not improve from 1.07089
# Epoch 344/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0805 - accuracy: 0.4196 - recall: 0.6375 - val_loss: 1.0040 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00344: loss did not improve from 1.07089
# Epoch 345/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0806 - accuracy: 0.4126 - recall: 0.6585 - val_loss: 0.9735 - val_accuracy: 0.5312 - val_recall: 0.9545
#
# Epoch 00345: loss did not improve from 1.07089
# Epoch 346/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0760 - accuracy: 0.4301 - recall: 0.6533 - val_loss: 1.0187 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00346: loss did not improve from 1.07089
# Epoch 347/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0859 - accuracy: 0.3986 - recall: 0.6125 - val_loss: 1.0054 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00347: loss did not improve from 1.07089
# Epoch 348/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0838 - accuracy: 0.4178 - recall: 0.6568 - val_loss: 0.9830 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00348: loss did not improve from 1.07089
# Epoch 349/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0765 - accuracy: 0.4318 - recall: 0.6387 - val_loss: 1.0320 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00349: loss did not improve from 1.07089
# Epoch 350/20000
# 143/143 [==============================] - 96s 671ms/step - loss: 1.0781 - accuracy: 0.4161 - recall: 0.6597 - val_loss: 1.0034 - val_accuracy: 0.5000 - val_recall: 0.9375
#
# Epoch 00350: loss did not improve from 1.07089
# Epoch 351/20000
# 143/143 [==============================] - 96s 673ms/step - loss: 1.0778 - accuracy: 0.4406 - recall: 0.6807 - val_loss: 0.9683 - val_accuracy: 0.6250 - val_recall: 0.9500
#
# Epoch 00351: loss did not improve from 1.07089
# Epoch 352/20000
# 143/143 [==============================] - 96s 672ms/step - loss: 1.0863 - accuracy: 0.4126 - recall: 0.6142 - val_loss: 0.9440 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00352: loss did not improve from 1.07089
# Epoch 353/20000
# 143/143 [==============================] - 96s 669ms/step - loss: 1.0820 - accuracy: 0.4038 - recall: 0.6533 - val_loss: 1.0111 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00353: loss did not improve from 1.07089
# Epoch 354/20000
# 143/143 [==============================] - 96s 670ms/step - loss: 1.0741 - accuracy: 0.4423 - recall: 0.6871 - val_loss: 1.0770 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00354: loss did not improve from 1.07089
# Epoch 355/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0780 - accuracy: 0.4143 - recall: 0.6247 - val_loss: 1.0130 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00355: loss did not improve from 1.07089
# Epoch 356/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0776 - accuracy: 0.4318 - recall: 0.6538 - val_loss: 0.9764 - val_accuracy: 0.5625 - val_recall: 0.9545
#
# Epoch 00356: loss did not improve from 1.07089
# Epoch 357/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0833 - accuracy: 0.4091 - recall: 0.5583 - val_loss: 1.0260 - val_accuracy: 0.5625 - val_recall: 0.9375
#
# Epoch 00357: loss did not improve from 1.07089
# Epoch 358/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0753 - accuracy: 0.4388 - recall: 0.6533 - val_loss: 0.9633 - val_accuracy: 0.5938 - val_recall: 0.9583
#
# Epoch 00358: loss did not improve from 1.07089
# Epoch 359/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0864 - accuracy: 0.3969 - recall: 0.6183 - val_loss: 0.9921 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00359: loss did not improve from 1.07089
# Epoch 360/20000
# 143/143 [==============================] - 97s 675ms/step - loss: 1.0814 - accuracy: 0.4301 - recall: 0.6696 - val_loss: 0.9708 - val_accuracy: 0.5938 - val_recall: 1.0000
#
# Epoch 00360: loss did not improve from 1.07089
# Epoch 361/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0850 - accuracy: 0.3969 - recall: 0.6282 - val_loss: 1.0286 - val_accuracy: 0.5625 - val_recall: 0.9375
#
# Epoch 00361: loss did not improve from 1.07089
# Epoch 362/20000
# 143/143 [==============================] - 96s 674ms/step - loss: 1.0742 - accuracy: 0.4371 - recall: 0.6463 - val_loss: 1.0419 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00362: loss did not improve from 1.07089
# Epoch 363/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0816 - accuracy: 0.4266 - recall: 0.6900 - val_loss: 1.0292 - val_accuracy: 0.5312 - val_recall: 0.9500
#
# Epoch 00363: loss did not improve from 1.07089
# Epoch 364/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0791 - accuracy: 0.4196 - recall: 0.6480 - val_loss: 1.0328 - val_accuracy: 0.5625 - val_recall: 0.9375
#
# Epoch 00364: loss did not improve from 1.07089
# Epoch 365/20000
# 143/143 [==============================] - 96s 675ms/step - loss: 1.0807 - accuracy: 0.4266 - recall: 0.6550 - val_loss: 0.9823 - val_accuracy: 0.5625 - val_recall: 0.9444
#
# Epoch 00365: loss did not improve from 1.07089
# Epoch 366/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0768 - accuracy: 0.4283 - recall: 0.6369 - val_loss: 1.0398 - val_accuracy: 0.5625 - val_recall: 0.9583
#
# Epoch 00366: loss did not improve from 1.07089
# Epoch 367/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0804 - accuracy: 0.4161 - recall: 0.6562 - val_loss: 0.9626 - val_accuracy: 0.5938 - val_recall: 0.9444
#
# Epoch 00367: loss did not improve from 1.07089
# Epoch 368/20000
# 143/143 [==============================] - 97s 676ms/step - loss: 1.0768 - accuracy: 0.4441 - recall: 0.6859 - val_loss: 1.0331 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00368: loss did not improve from 1.07089
# Epoch 369/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0836 - accuracy: 0.4038 - recall: 0.6096 - val_loss: 0.9717 - val_accuracy: 0.5938 - val_recall: 0.9500
#
# Epoch 00369: loss did not improve from 1.07089
# Epoch 370/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0788 - accuracy: 0.4266 - recall: 0.6084 - val_loss: 1.0552 - val_accuracy: 0.5000 - val_recall: 0.9545
#
# Epoch 00370: loss did not improve from 1.07089
# Epoch 371/20000
# 143/143 [==============================] - 98s 682ms/step - loss: 1.0766 - accuracy: 0.4336 - recall: 0.6964 - val_loss: 1.0317 - val_accuracy: 0.5625 - val_recall: 0.9375
#
# Epoch 00371: loss did not improve from 1.07089
# Epoch 372/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0715 - accuracy: 0.4493 - recall: 0.6836 - val_loss: 1.0575 - val_accuracy: 0.5312 - val_recall: 0.9286
#
# Epoch 00372: loss did not improve from 1.07089
# Epoch 373/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0756 - accuracy: 0.4301 - recall: 0.7028 - val_loss: 0.9629 - val_accuracy: 0.5938 - val_recall: 0.9583
#
# Epoch 00373: loss did not improve from 1.07089
# Epoch 374/20000
# 143/143 [==============================] - 98s 685ms/step - loss: 1.0778 - accuracy: 0.4371 - recall: 0.6649 - val_loss: 0.9773 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00374: loss did not improve from 1.07089
# Epoch 375/20000
# 143/143 [==============================] - 98s 686ms/step - loss: 1.0814 - accuracy: 0.4196 - recall: 0.6329 - val_loss: 0.9747 - val_accuracy: 0.5312 - val_recall: 0.9375
#
# Epoch 00375: loss did not improve from 1.07089
# Epoch 376/20000
# 143/143 [==============================] - 96s 675ms/step - loss: 1.0748 - accuracy: 0.4283 - recall: 0.6428 - val_loss: 1.0103 - val_accuracy: 0.5938 - val_recall: 0.9444
#
# Epoch 00376: loss did not improve from 1.07089
# Epoch 377/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0744 - accuracy: 0.4371 - recall: 0.6597 - val_loss: 0.9967 - val_accuracy: 0.5312 - val_recall: 0.9444
#
# Epoch 00377: loss did not improve from 1.07089
# Epoch 378/20000
# 143/143 [==============================] - 97s 681ms/step - loss: 1.0797 - accuracy: 0.4073 - recall: 0.6329 - val_loss: 0.9859 - val_accuracy: 0.6250 - val_recall: 1.0000
#
# Epoch 00378: loss did not improve from 1.07089
# Epoch 379/20000
# 143/143 [==============================] - 97s 679ms/step - loss: 1.0806 - accuracy: 0.4266 - recall: 0.6801 - val_loss: 1.0342 - val_accuracy: 0.5312 - val_recall: 1.0000
#
# Epoch 00379: loss did not improve from 1.07089
# Epoch 380/20000
# 143/143 [==============================] - 97s 680ms/step - loss: 1.0826 - accuracy: 0.4143 - recall: 0.6300 - val_loss: 1.0452 - val_accuracy: 0.5625 - val_recall: 1.0000
#
# Epoch 00380: loss did not improve from 1.07089
# Epoch 381/20000
# 143/143 [==============================] - 97s 678ms/step - loss: 1.0776 - accuracy: 0.4301 - recall: 0.6573 - val_loss: 0.9833 - val_accuracy: 0.5000 - val_recall: 0.9286
#
# Epoch 00381: loss did not improve from 1.07089
# Epoch 382/20000
# 143/143 [==============================] - 97s 677ms/step - loss: 1.0801 - accuracy: 0.4283 - recall: 0.6661 - val_loss: 0.9966 - val_accuracy: 0.5625 - val_recall: 0.9500
#
# Epoch 00382: loss did not improve from 1.07089
# Epoch 383/20000
# 143/143 [==============================] - 98s 688ms/step - loss: 1.0813 - accuracy: 0.4073 - recall: 0.6276 - val_loss: 0.9827 - val_accuracy: 0.5000 - val_recall: 0.9545
#
# Epoch 00383: loss did not improve from 1.07089
# Epoch 384/20000
# 143/143 [==============================] - 98s 687ms/step - loss: 1.0787 - accuracy: 0.4213 - recall: 0.6643 - val_loss: 0.9828 - val_accuracy: 0.5938 - val_recall: 0.9500
#
# Epoch 00384: loss did not improve from 1.07089
# Epoch 385/20000
#  31/143 [=====>........................] - ETA: 1:13 - loss: 1.0812 - accuracy: 0.3952 - recall: 0.5753Buffered data was truncated after reaching the output size limit.
